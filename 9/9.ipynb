# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['agg.path.chunksize'] = 1024
from xgboost import XGBRegressor

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 9.0 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostRegressor, Pool

# %%
from lightgbm import LGBMRegressor,plot_importance
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import gc
import warnings
warnings.filterwarnings("ignore")

# %%
col_names=["","Duration","Distance","PLong","PLatd","DLong","DLatd","Haversine","Pmonth","Pday","Phour","Pmin","PDweek","Dmonth","Dday","Dhour","Dmin","DDweek","Temp","Precip","Wind","Humid","Solar","Snow","GroundTemp","Dust"]
df1 = pd.read_csv('For_modeling.csv',header=None,names=col_names,low_memory=False)

# df.drop('', inplace=True, axis=1)
# df1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d855a37911fd> in <cell line: 4>()
#       2 df1 = pd.read_csv('For_modeling.csv',header=None,names=col_names,low_memory=False)
#       3 df = df1.drop("", axis = 1, inplace=True)
# ----> 4 df.head()
#       5 # df.drop('', inplace=True, axis=1)
#       6 # df1.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
 df1.head()
# Out:
#    Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0  Duration  Distance      PLong       PLatd      DLong       DLatd
# 1         3        50  37.544666  126.888359  37.544666  126.888359
# 2        24      7670  37.506199  127.003944   37.55125  127.035103
# 3         8      1390   37.54459  127.057083  37.537014  127.061096
# 4         8      1820  37.571102   127.02356  37.561447   127.03492
#
#             Haversine  Pmonth  Pday  Phour  ...  Dmin  DDweek  Temp  Precip  \
# 0           Haversine  Pmonth  Pday  Phour  ...  Dmin  DDweek  Temp  Precip
# 1                 0.0       1     1      0  ...     4       0  -3.2     0.0
# 2   5.713528999751687       1     1      0  ...    25       0  -3.2     0.0
# 3  0.9137016437363148       1     1      0  ...     9       0  -3.2     0.0
# 4  1.4680270819019492       1     1      0  ...    10       0  -3.2     0.0
#
#    Wind  Humid  Solar  Snow  GroundTemp  Dust
# 0  Wind  Humid  Solar  Snow  GroundTemp  Dust
# ...

# %%
df1.isna().sum()
# Out:
# Duration      0
# Distance      0
# PLong         0
# PLatd         0
# DLong         0
# DLatd         0
# Haversine     0
# Pmonth        1
# Pday          1
# Phour         1
# Pmin          1
# PDweek        1
# Dmonth        1
# Dday          1
# Dhour         1
# Dmin          1
# DDweek        1
# Temp          1
# Precip        1
# Wind          1
# Humid         1
# Solar         1
# Snow          1
# GroundTemp    1
# Dust          1
# dtype: int64

# %%
X, y = df1.drop("Duration", axis = 1), df1.Duration
df1.head()
# Out:
#    Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0  Duration  Distance      PLong       PLatd      DLong       DLatd
# 1         3        50  37.544666  126.888359  37.544666  126.888359
# 2        24      7670  37.506199  127.003944   37.55125  127.035103
# 3         8      1390   37.54459  127.057083  37.537014  127.061096
# 4         8      1820  37.571102   127.02356  37.561447   127.03492
#
#             Haversine  Pmonth  Pday  Phour  ...  Dmin  DDweek  Temp  Precip  \
# 0           Haversine  Pmonth  Pday  Phour  ...  Dmin  DDweek  Temp  Precip
# 1                 0.0       1     1      0  ...     4       0  -3.2     0.0
# 2   5.713528999751687       1     1      0  ...    25       0  -3.2     0.0
# 3  0.9137016437363148       1     1      0  ...     9       0  -3.2     0.0
# 4  1.4680270819019492       1     1      0  ...    10       0  -3.2     0.0
#
#    Wind  Humid  Solar  Snow  GroundTemp  Dust
# 0  Wind  Humid  Solar  Snow  GroundTemp  Dust
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
df = df1.dropna(axis=1)
df.head()
# Out:
#    Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0  Duration  Distance      PLong       PLatd      DLong       DLatd
# 1         3        50  37.544666  126.888359  37.544666  126.888359
# 2        24      7670  37.506199  127.003944   37.55125  127.035103
# 3         8      1390   37.54459  127.057083  37.537014  127.061096
# 4         8      1820  37.571102   127.02356  37.561447   127.03492
#
#             Haversine
# 0           Haversine
# 1                 0.0
# 2   5.713528999751687
# 3  0.9137016437363148
# 4  1.4680270819019492

# %%
X_train = X_train.fillna(X_train.mean())
X_test = X_test.fillna(X_train.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0e1fe4acb4fb> in <cell line: 1>()
# ----> 1 X_train = X_train.fillna(X_train.mean())
#       2 X_test = X_test.fillna(X_train.mean())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11199         **kwargs,
#   11200     ) -> Series | float:
# > 11201         return self._stat_function(
#   11202             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203         )
#
# ...

# %% [markdown]
# **Gradient Boosting**

# %%
GBR = GradientBoostingRegressor(n_estimators = 50, learning_rate = 0.1, max_depth = 8, subsample = 0.8)

# %%
GBR.fit(X_train, y_train)
gbr_pred = GBR.predict(X_test)
mse_gbr = mean_squared_error(y_test, gbr_pred)

# %%
print("Mean squared error of Gradient Boost: ",mse_gbr)
# Out:
# Mean squared error of Gradient Boost:  82.77208106780088

# %% [markdown]
# **XG Boost**

# %%
XGB = XGBRegressor(n_estimators = 50, learning_rate = 0.1, max_depth = 8, subsample = 0.8)

# %%
XGB.fit(x_train, y_train)
xgb_pred = XGB.predict(x_test)
mse_xgb = mean_squared_error(y_test, xgb_pred)
print("Mean squared error of Xtreme Gradient Boost: ",mse_xgb)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-14fb9fc7e44f> in <cell line: 1>()
# ----> 1 XGB.fit(X_train, y_train)
#       2 xgb_pred = XGB.predict(X_test)
#       3 mse_xgb = mean_squared_error(y_test, xgb_pred)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     728             for k, arg in zip(sig.parameters, args):
#     729                 kwargs[k] = arg
# --> 730             return func(**kwargs)
#     731
#     732         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1053         with config_context(verbosity=self.verbosity):
# ...

# %%
print("Mean squared error of Xtreme Gradient Boost: ",mse_xgb)

# %% [markdown]
# **ADA Boosting**

# %%
ada_boost = AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=8), n_estimators=50, learning_rate=0.1)

ada_boost.fit(x_train, y_train)
ada_pred = ada_boost.predict(x_test)
mse_ada = mean_squared_error(y_test, ada_pred)
print("Mean squared error of AdaBoostRegressor:", mse_ada)

# %% [markdown]
# **Cat Boosting**

# %%
cat_features = ['Pmonth', 'Pday', 'Phour', 'PDweek', 'Dmonth', 'Dday', 'Dhour', 'DDweek']
X_train[cat_features] = X_train[cat_features].astype(str)
X_test[cat_features] = X_test[cat_features].astype(str)

CatB = CatBoostRegressor(n_estimators = 50, learning_rate = 0.1, max_depth = 8, subsample = 0.8)

p_train = Pool(X_train, y_train, cat_features)
p_test = Pool(X_test, y_test, cat_features)
CatB.fit(p_train)
catb_pred = CatB.predict(p_test)
mse_cat1 = mean_squared_error(y_test, catb_pred)
print("Mean squared error of Cat Boost with pool: ",mse_cat1)
# Out:
# 0:	learn: 22.5373958	total: 1.54s	remaining: 1m 15s
# 1:	learn: 21.2496332	total: 2.78s	remaining: 1m 6s
# 2:	learn: 20.1369714	total: 4.08s	remaining: 1m 3s
# 3:	learn: 19.1864471	total: 5.03s	remaining: 57.9s
# 4:	learn: 18.3649840	total: 5.63s	remaining: 50.6s
# 5:	learn: 17.6745853	total: 6.25s	remaining: 45.8s
# 6:	learn: 17.0718370	total: 7s	remaining: 43s
# 7:	learn: 16.5394182	total: 7.62s	remaining: 40s
# 8:	learn: 16.0961043	total: 8.28s	remaining: 37.7s
# 9:	learn: 15.7216231	total: 8.94s	remaining: 35.8s
# 10:	learn: 15.4020241	total: 9.62s	remaining: 34.1s
# 11:	learn: 15.1399677	total: 10.3s	remaining: 32.5s
# 12:	learn: 14.9141598	total: 10.9s	remaining: 31.1s
# 13:	learn: 14.7148587	total: 11.6s	remaining: 29.8s
# 14:	learn: 14.5536739	total: 12.3s	remaining: 28.6s
# 15:	learn: 14.4206295	total: 12.9s	remaining: 27.5s
# 16:	learn: 14.3044642	total: 13.6s	remaining: 26.3s
# 17:	learn: 14.2026341	total: 14.3s	remaining: 25.4s
# ...
