# %%
import pandas as pd
from mlxtend.frequent_patterns import association_rules, fpgrowth

# %%
df = pd.read_csv('Market_Basket_Optimisation.csv',sep=',',header=None)
df.fillna("", inplace=True)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs
# 2        chutney
# 3         turkey    avocado
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1
# 2
# 3
# 4
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1
# 2
# 3
# 4
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1
# 2
# 3
# 4

# %%
items = set()
for col in df:
    unique_values = df[col].unique()
    for val in unique_values:
        if val != "":
            items.add(val)

print(items)
# Out:
# {'whole wheat pasta', 'burger sauce', 'mashed potato', 'champagne', 'escalope', 'whole weat flour', 'avocado', 'frozen smoothie', 'extra dark chocolate', 'gums', 'ground beef', 'pepper', 'strawberries', 'ham', 'eggplant', 'zucchini', 'protein bar', 'green beans', 'salt', 'chocolate bread', 'pancakes', 'napkins', 'spaghetti', 'cider', 'cooking oil', 'sandwich', 'cottage cheese', 'turkey', 'rice', 'burgers', 'shrimp', ' asparagus', 'shallot', 'chili', 'toothpaste', 'grated cheese', 'light cream', 'nonfat milk', 'energy drink', 'parmesan cheese', 'soda', 'whole wheat rice', 'bramble', 'white wine', 'black tea', 'asparagus', 'low fat yogurt', 'red wine', 'spinach', 'salmon', 'fresh tuna', 'fresh bread', 'energy bar', 'herb & pepper', 'eggs', 'mineral water', 'mint green tea', 'french wine', 'oatmeal', 'shampoo', 'chocolate', 'blueberries', 'barbecue sauce', 'yogurt cake', 'tomato sauce', 'cereals', 'water spray', 'antioxydant juice', 'tomatoes', 'meatballs', 'melons', 'pet food', 'chutney', 'muffins', 'bacon', 'mushroom cream sauce', 'cauliflower', 'oil', 'yams', 'frozen vegetables', 'tea', 'clothes accessories', 'milk', 'brownies', 'salad', 'french fries', 'hand protein bar', 'gluten free bar', 'green tea', 'babies food', 'mayonnaise', 'body spray', 'corn', 'light mayo', 'hot dogs', 'pickles', 'green grapes', 'bug spray', 'pasta', 'chicken', 'honey', 'candy bars', 'cake', 'olive oil', 'sparkling water', 'strong cheese', 'cookies', 'carrots', 'almonds', 'ketchup', 'soup', 'mint', 'magazines', 'cream', 'butter', 'flax seed', 'fromage blanc', 'dessert wine', 'tomato juice', 'vegetables mix'}
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
itemset = set(items)
encoded_vals = []
for index, row in df.iterrows():
    rowset = set(row)
    labels = {}
    uncommons = list(itemset - rowset)
    commons = list(itemset.intersection(rowset))
    for uc in uncommons:
        labels[uc] = 0
    for com in commons:
        labels[com] = 1
    encoded_vals.append(labels)
encoded_vals[0]
ohe_df = pd.DataFrame(encoded_vals)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fp = fpgrowth(ohe_df, min_support=0.02, use_colnames=True)
fp
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                      itemsets
# 0    0.238368               (mineral water)
# 1    0.132116                   (green tea)
# 2    0.076523              (low fat yogurt)
# 3    0.071457                      (shrimp)
# 4    0.065858                   (olive oil)
# ..        ...                           ...
# 98   0.040928  (ground beef, mineral water)
# 99   0.039195      (spaghetti, ground beef)
# 100  0.021997           (milk, ground beef)
# 101  0.023064      (chocolate, ground beef)
# 102  0.027463         (cake, mineral water)
#
# [103 rows x 2 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
association_rules(fp,metric="confidence",min_threshold=0.1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents      consequents  antecedent support  consequent support  \
# 0       (green tea)  (mineral water)            0.132116            0.238368
# 1   (mineral water)      (green tea)            0.238368            0.132116
# 2       (green tea)      (spaghetti)            0.132116            0.174110
# 3       (spaghetti)      (green tea)            0.174110            0.132116
# 4       (green tea)   (french fries)            0.132116            0.170911
# ..              ...              ...                 ...                 ...
# 89    (ground beef)           (milk)            0.098254            0.129583
# 90      (chocolate)    (ground beef)            0.163845            0.098254
# 91    (ground beef)      (chocolate)            0.098254            0.163845
# 92           (cake)  (mineral water)            0.081056            0.238368
# 93  (mineral water)           (cake)            0.238368            0.081056
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 0   0.031063    0.235116  0.986357 -0.000430    0.995748      -0.015688
# 1   0.031063    0.130313  0.986357 -0.000430    0.997927      -0.017837
# 2   0.026530    0.200807  1.153335  0.003527    1.033405       0.153188
# 3   0.026530    0.152374  1.153335  0.003527    1.023900       0.160977
# 4   0.028530    0.215943  1.263488  0.005950    1.057436       0.240286
# ..       ...         ...       ...       ...         ...            ...
# 89  0.021997    0.223881  1.727704  0.009265    1.121499       0.467090
# 90  0.023064    0.140765  1.432669  0.006965    1.049476       0.361180
# 91  0.023064    0.234735  1.432669  0.006965    1.092635       0.334908
# 92  0.027463    0.338816  1.421397  0.008142    1.151921       0.322617
# 93  0.027463    0.115213  1.421397  0.008142    1.038604       0.389252
#
# [94 rows x 10 columns]
