#   0.81246618 -0.22812681 -1.15213832 -0.21592597 -1.18227289 -0.06985304
#   1.07467334  2.05458263  0.26189883 -1.38484381  2.03774274 -1.1036554
#   0.93890744  1.54357096 -1.25985898  2.10422641  0.21929365 -0.37980613
#   0.13251532 -0.81906868 -0.59844786  0.48392588 -0.14584826 -0.64055455
#   1.50982937  1.54643499 -1.24223906 -1.06292659]

# %%
#count plot
import seaborn as sns
import matplotlib.pyplot as plt


df = sns.load_dataset('tips')

# count plot on single categorical variable
sns.countplot(x ='sex', data = df)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#univariate; histogram

import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

data.describe()

plt.hist(data.LoanAmount, bins = 200)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histogram')
# Out:
# Text(0.5, 1.0, 'Basic Histogram')

# %%
#univariate; violin plot

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data1 = pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

print(data1.CoapplicantIncome)

sns.set(style = 'whitegrid')
sns.violinplot(x="CoapplicantIncome",data = data1)
# Out:
# 0         0.0
# 1      1508.0
# 2         0.0
# 3      2358.0
# 4         0.0
#         ...
# 609       0.0
# 610       0.0
# 611     240.0
# 612       0.0
# 613       0.0
# Name: CoapplicantIncome, Length: 614, dtype: float64
# <Axes: xlabel='CoapplicantIncome'>

# %%
#univariate; bar graph

import pandas as pd
from matplotlib import pyplot as plt


data = pd.read_csv("train_u6lujuX_CVtuZ9i.csv")

gen = data['Gender'].value_counts()
gen.plot(kind = 'bar')
plt.show()

# %%
#bivariate;scatterplot

import random
import matplotlib.pyplot as plt
import numpy as np


data = pd.read_csv("train_u6lujuX_CVtuZ9i.csv")

data1 = data.ApplicantIncome
data2 = data.LoanAmount

print(data1)
print(data2)

plt.scatter(data1,data2, color='skyblue', edgecolor='black')
plt.xlabel('ApplicantIncome')
plt.ylabel('LoanAmount')
plt.title('Scatter Plot')

plt.show()
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
#bivariate;countplot

import seaborn as sns
import pandas as pd

df = pd.read_csv("train_u6lujuX_CVtuZ9i.csv")

sns.countplot(x ='Education',hue="Loan_Status", data = df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
#univariate; bar graph

import pandas as pd
import seaborn as sns

df = pd.read_csv("train_u6lujuX_CVtuZ9i.csv")
sns.barplot(x = 'Gender', y = 'ApplicantIncome',  data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>

# %%
#multivariate  ; heatmap

import pandas as pd
import seaborn as sns

df = pd.read_csv("train_u6lujuX_CVtuZ9i.csv")

sns.heatmap(df.corr(),annot = True)
# Out:
# <ipython-input-77-981acc866b2c>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True)
# <Axes: >

# %%
#multivariate; barplot

import pandas as pd
import seaborn as sns

df = pd.read_csv("train_u6lujuX_CVtuZ9i.csv")
sns.barplot(x = 'Gender', y = 'ApplicantIncome',  hue = "Loan_Status", data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>
